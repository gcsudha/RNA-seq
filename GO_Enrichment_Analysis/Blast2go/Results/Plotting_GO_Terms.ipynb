# %%
library(ggplot2)
library(dplyr)

# %%
combined = read.csv('C:/Users/sudha.gcupadhaya/Desktop/RNA-seq/GO_Enrichment_Analysis/Blast2go/Results/Data/Top_20_combined.csv')

# %%
names(combined) = c('Gene_ID', 'GO_Name', 'Category','fdr', 'P', 'count', 'ref_count', 'Host', 'Percent')

# %%
combined = combined[combined$Host=='Potato',]

# %%
combined$GO_Name = with(combined, factor(GO_Name, levels= GO_Name[order(Category)]))

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
#tiff('mint.tiff',width=18,height=8,units='in',res=300)
a = ggplot(combined, aes(x= GO_Name, y= count, fill = Category))+
           geom_bar(stat = 'identity')+
           theme_bw()+
    labs(title ='', x = 'GO Term', y = '', fill = 'GO Category', color = 'black')+
    theme(axis.title.x= element_text(size =14, color ='black'),
    axis.title.y = element_text(size =14, color ='black'),
    axis.text.x = element_text(vjust =1, hjust = 1, size =12,angle =45,color = 'black'),
    axis.text.y = element_text(size =12, color = 'black'),
    plot.margin=unit(c(1,1,1,3),"cm"), # top, right, bottom, left  
    
    legend.text = element_text(size =12),
    legend.title = element_text(size =14))+
    
    theme(legend.position="bottom")+
    scale_fill_manual(labels = c('Biological Process', 'Cellular Component', 'Molecular Function'), 
                             values = c('indianred', 'orange', 'cornflowerblue'))
a
#dev.off()
# Out:
# plot without title

# %%
options(repr.plot.width = 18, repr.plot.height = 20)
ggplot(combined, aes(x= GO_Name, y= count, fill = Category))+
           geom_col(position = 'stack')+
           theme_bw()+
    theme(axis.title.x= element_text(size =10, color ='black'),
    axis.title.y = element_text(size =10, color ='black'),
    axis.text.x = element_text(vjust =1, hjust = 1, size =10,angle =45,color = 'black'),
    axis.text.y = element_text(size =10, color = 'black'),
    plot.margin=unit(c(1,1,1,2),"cm"), # top, right, bottom, left  
    strip.text.x = element_text(size = 10),
    strip.text.y = element_text(size = 10),
    legend.text = element_text(size =10),
    legend.title = element_text(size =10))+
    facet_wrap(~Host, scale = 'free', ncol =1)
# Out:
# plot without title

# %%
setwd('C:/Users/sudha.gcupadhaya/Desktop/RNA-seq/GO_Enrichment_Analysis/Blast2go/Results/')
go_potato = read.csv('potato_GOTerms.csv')
go_potato$host = 'potato'
go_mustard = read.csv('mustard_GOTerms.csv')
go_mustard$host = 'mustard'
go_mint = read.csv('mint_GOTerms.csv')
go_mint$host = 'mint'
go_vd = read.csv('Vd_GOTerms.csv')
go_vd$host = 'Vd'

# %%
list = go_mint$GO.Name
a = go_potato[go_potato$GO.Name %in% list, ]

# %%
b = go_mint[go_mint$GO.Name %in% a,]

# %%
unique(combined$Host)
# Out:
# [1] Potato  Mustard Mint
# Levels: Mint Mustard Potato

# %%
b
# Out:
#    Tags   GO.ID      GO.Name                             GO.Category
# 2  [OVER] GO:0003824 catalytic activity                  MOLECULAR_FUNCTION
# 8  [OVER] GO:0044281 small molecule metabolic process    BIOLOGICAL_PROCESS
# 13 [OVER] GO:0006082 organic acid metabolic process      BIOLOGICAL_PROCESS
# 20 [OVER] GO:0043436 oxoacid metabolic process           BIOLOGICAL_PROCESS
# 21 [OVER] GO:0019752 carboxylic acid metabolic process   BIOLOGICAL_PROCESS
# 34 [OVER] GO:0044283 small molecule biosynthetic process BIOLOGICAL_PROCESS
# 37 [OVER] GO:0016491 oxidoreductase activity             MOLECULAR_FUNCTION
# 51 [OVER] GO:0016829 lyase activity                      MOLECULAR_FUNCTION
#    FDR          P.Value      Nr.Test Nr.Reference Non.Annot.Test
# 2  6.010000e-11 1.100000e-14 692     55317         503
# 8  1.110000e-07 6.050000e-11 195     12047        1000
# 13 1.130000e-05 2.270000e-08 117      6760        1078
# 20 1.260000e-05 2.760000e-08 116      6709        1079
# 21 4.270000e-05 1.010000e-07 113      6651        1082
# 34 1.059742e-03 5.870000e-06  71      3988        1124
# 37 2.300000e-06 2.940000e-09 194     12572        1001
# 51 4.098592e-02 1.069814e-03  42      2469        1153
#    Non.Annot.Reference host
# 2   62940              mint
# 8  106210              mint
# 13 111497              mint
# 20 111548              mint
# 21 111606              mint
# 34 114269              mint
# 37 105685              mint
# 51 115788              mint
